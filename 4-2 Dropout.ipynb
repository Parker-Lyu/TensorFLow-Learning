# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
# 载入数据
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)s
# Out:
# WARNING:tensorflow:From <ipython-input-2-911ded80008e>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From D:\SoftWare\Anaconda3\envs\pyDL\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From D:\SoftWare\Anaconda3\envs\pyDL\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From D:\SoftWare\Anaconda3\envs\pyDL\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\SoftWare\Anaconda3\envs\pyDL\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From D:\SoftWare\Anaconda3\envs\pyDL\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
# 批次的大小
batch_size = 128
n_batch = mnist.train.num_examples // batch_size

x = tf.placeholder(tf.float32, [None,784])
y = tf.placeholder(tf.float32, [None, 10])
keep_prob = tf.placeholder(tf.float32)

# 创建神经网络
W1 = tf.Variable(tf.truncated_normal([784,2000],stddev=0.1))
b1 = tf.Variable(tf.zeros([1, 2000]))
# 激活层
layer1 = tf.nn.relu(tf.matmul(x,W1) + b1)
# drop层
layer1 = tf.nn.dropout(layer1,keep_prob=keep_prob)

# 第二层
W2 = tf.Variable(tf.truncated_normal([2000,500],stddev=0.1))
b2 = tf.Variable(tf.zeros([1, 500]))
layer2 = tf.nn.relu(tf.matmul(layer1,W2) + b2)
layer2 = tf.nn.dropout(layer2,keep_prob=keep_prob)

# 第三层
W3 = tf.Variable(tf.truncated_normal([500,10],stddev=0.1))
b3 = tf.Variable(tf.zeros([1,10]))
prediction = tf.nn.sigmoid(tf.matmul(layer2,W3) + b3)

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))

# 梯度下降法
# train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)#得到97的正确率
train_step = tf.train.AdadeltaOptimizer(0.1).minimize(loss)


# 初始化变量
init = tf.global_variables_initializer()

prediction_2 = tf.nn.softmax(prediction)
# 得到一个布尔型列表，存放结果是否正确
correct_prediction = tf.equal(tf.argmax(y,1), tf.argmax(prediction_2,1)) #argmax 返回一维张量中最大值索引

# 求准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32)) # 把布尔值转换为浮点型求平均数

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(100):
        for batch in range(n_batch):
            # 获得批次数据
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x:batch_xs, y:batch_ys, keep_prob:0.8})
        acc = sess.run(accuracy, feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0} )
        print("Iter " + str(epoch) + " Testing Accuracy: " + str(acc))
# Out:
# Iter 0 Testing Accuracy: 0.882
# Iter 1 Testing Accuracy: 0.9054
# Iter 2 Testing Accuracy: 0.916
# Iter 3 Testing Accuracy: 0.9242
# Iter 4 Testing Accuracy: 0.9294
# Iter 5 Testing Accuracy: 0.9344
# Iter 6 Testing Accuracy: 0.937
# Iter 7 Testing Accuracy: 0.9385
# Iter 8 Testing Accuracy: 0.9414
# Iter 9 Testing Accuracy: 0.9442
# Iter 10 Testing Accuracy: 0.9458
# Iter 11 Testing Accuracy: 0.9469
# Iter 12 Testing Accuracy: 0.949
# Iter 13 Testing Accuracy: 0.9501
# Iter 14 Testing Accuracy: 0.9508
# Iter 15 Testing Accuracy: 0.9512
# Iter 16 Testing Accuracy: 0.9526
# Iter 17 Testing Accuracy: 0.9535
# Iter 18 Testing Accuracy: 0.9541
# Iter 19 Testing Accuracy: 0.9559
# Iter 20 Testing Accuracy: 0.9571
# Iter 21 Testing Accuracy: 0.9575
# Iter 22 Testing Accuracy: 0.9579
# Iter 23 Testing Accuracy: 0.9587
# Iter 24 Testing Accuracy: 0.9589
# Iter 25 Testing Accuracy: 0.96
# Iter 26 Testing Accuracy: 0.9606
# Iter 27 Testing Accuracy: 0.9611
# Iter 28 Testing Accuracy: 0.962
# Iter 29 Testing Accuracy: 0.9624
# Iter 30 Testing Accuracy: 0.9622
# Iter 31 Testing Accuracy: 0.9628
# Iter 32 Testing Accuracy: 0.9634
# Iter 33 Testing Accuracy: 0.9639
# Iter 34 Testing Accuracy: 0.9641
# Iter 35 Testing Accuracy: 0.9649
# Iter 36 Testing Accuracy: 0.9648
# Iter 37 Testing Accuracy: 0.9653
# Iter 38 Testing Accuracy: 0.9656
# Iter 39 Testing Accuracy: 0.9662
# Iter 40 Testing Accuracy: 0.9665
# Iter 41 Testing Accuracy: 0.9673
# Iter 42 Testing Accuracy: 0.968
# Iter 43 Testing Accuracy: 0.9678
# Iter 44 Testing Accuracy: 0.9679
# Iter 45 Testing Accuracy: 0.9686
# Iter 46 Testing Accuracy: 0.968
# Iter 47 Testing Accuracy: 0.9688
# Iter 48 Testing Accuracy: 0.9692
# Iter 49 Testing Accuracy: 0.9692
# Iter 50 Testing Accuracy: 0.9699
# Iter 51 Testing Accuracy: 0.9698
# Iter 52 Testing Accuracy: 0.9702
# Iter 53 Testing Accuracy: 0.9699
# Iter 54 Testing Accuracy: 0.9703
# Iter 55 Testing Accuracy: 0.9706
# Iter 56 Testing Accuracy: 0.9711
# Iter 57 Testing Accuracy: 0.9712
# Iter 58 Testing Accuracy: 0.9715
# Iter 59 Testing Accuracy: 0.9711
# Iter 60 Testing Accuracy: 0.9714
# Iter 61 Testing Accuracy: 0.9722
# Iter 62 Testing Accuracy: 0.9717
# Iter 63 Testing Accuracy: 0.9716
# Iter 64 Testing Accuracy: 0.9725
# Iter 65 Testing Accuracy: 0.9725
# Iter 66 Testing Accuracy: 0.9725
# Iter 67 Testing Accuracy: 0.9727
# Iter 68 Testing Accuracy: 0.9728
# Iter 69 Testing Accuracy: 0.9727
# Iter 70 Testing Accuracy: 0.9729
# Iter 71 Testing Accuracy: 0.9735
# Iter 72 Testing Accuracy: 0.9733
# Iter 73 Testing Accuracy: 0.9741
# Iter 74 Testing Accuracy: 0.9736
# Iter 75 Testing Accuracy: 0.9735
# Iter 76 Testing Accuracy: 0.9738
# Iter 77 Testing Accuracy: 0.9743
# Iter 78 Testing Accuracy: 0.974
# Iter 79 Testing Accuracy: 0.9744
# Iter 80 Testing Accuracy: 0.9747
# Iter 81 Testing Accuracy: 0.9752
# Iter 82 Testing Accuracy: 0.9751
# Iter 83 Testing Accuracy: 0.9745
# Iter 84 Testing Accuracy: 0.975
# Iter 85 Testing Accuracy: 0.9749
# Iter 86 Testing Accuracy: 0.9753
# Iter 87 Testing Accuracy: 0.9756
# Iter 88 Testing Accuracy: 0.9752
# Iter 89 Testing Accuracy: 0.9761
# Iter 90 Testing Accuracy: 0.9759
# Iter 91 Testing Accuracy: 0.9764
# Iter 92 Testing Accuracy: 0.9768
# Iter 93 Testing Accuracy: 0.9764
# Iter 94 Testing Accuracy: 0.9766
# Iter 95 Testing Accuracy: 0.977
# Iter 96 Testing Accuracy: 0.9768
# Iter 97 Testing Accuracy: 0.9771
# Iter 98 Testing Accuracy: 0.977
# Iter 99 Testing Accuracy: 0.9767
